# %% [markdown]
# # Week 1

# %%
# Welcome message
course_name = "Practical Data Science: Tools for Social Change"
print(f"Welcome to {course_name}!")

# Your information (replace with your details)
student_name = "Lida Vaynberg"
background = "Supply Chain Management, Data Analytics, Social Impact & Grant Projects"
social_interest = "Textile waste management"

print(f"\nStudent: {student_name}")
print(f"Background: {background}")
print(f"Interested in: {social_interest}")
# Out:
# Welcome to Practical Data Science: Tools for Social Change!
#
# Student: Lida Vaynberg
# Background: Supply Chain Management, Data Analytics, Social Impact & Grant Projects
# Interested in: Textile waste management

# %%
# Global statistics (approximate values)
Textile_waste_collected_separately_2022_EU = 2_070_000  #  2,07 million tonnes
Textile_waste_collected_separately_2022_EU_Households = 910_000 #  910 thousand tonnes
Population_1_jan_2022_EU = 445_972_024  # 446 million people
Population_1_jan_2023_EU = 447_695_350  # 447,7 million people

# Calculate percentages
Households_percentage = (Textile_waste_collected_separately_2022_EU_Households/Textile_waste_collected_separately_2022_EU)*100
Mean_population_EU_2022 = (Population_1_jan_2022_EU+Population_1_jan_2023_EU)/2
Textile_waste_per_person_kg = Textile_waste_collected_separately_2022_EU*1000/Mean_population_EU_2022

print(f"Textile_waste_collected_separately_2022_EU (tonnes): {Textile_waste_collected_separately_2022_EU:,}")
print(f"Textile_waste_collected_separately_2022_EU_Households (tonnes): {Textile_waste_collected_separately_2022_EU_Households:,} ({Households_percentage:.0f}%)")
print(f"\nTextile waste per person (kg): {Textile_waste_per_person_kg:.2f}")
# Out:
# Textile_waste_collected_separately_2022_EU (tonnes): 2,070,000
# Textile_waste_collected_separately_2022_EU_Households (tonnes): 910,000 (44%)
#
# Textile waste per person (kg): 4.63

# %% [markdown]
# ## Part 3: Lists - Organizing Multiple Items
#
# Lists help us organize related information. Let's create lists of social issues and data sources.

# %%
# List of global social challenges
social_challenges = [
    "Climate Change",
    "Educational Inequality",
    "Healthcare Access",
    "Economic Inequality",
    "Food Security",
    "Clean Water Access"
]

print("Major Social Challenges:")
for i, challenge in enumerate(social_challenges, 1):
    print(f"{i}. {challenge}")

# Practice with list operations
print(f"\nTotal challenges listed: {len(social_challenges)}")
print(f"First challenge: {social_challenges[0]}")
print(f"Last challenge: {social_challenges[-1]}")

# Add a new challenge
social_challenges.append("Digital Divide")
print(f"\nAfter adding 'Digital Divide': {len(social_challenges)} challenges")
# Out:
# Major Social Challenges:
# 1. Climate Change
# 2. Educational Inequality
# 3. Healthcare Access
# 4. Economic Inequality
# 5. Food Security
# 6. Clean Water Access
#
# Total challenges listed: 6
# First challenge: Climate Change
# Last challenge: Clean Water Access
#
# After adding 'Digital Divide': 7 challenges

# %% [markdown]
# ## Part 4: Dictionaries - Key-Value Data
#
# Dictionaries let us store related information together using keys and values.

# %%
# Information about a social issue using a dictionary
climate_change_info = {
    "issue": "Climate Change",
    "affected_population": "All humans, especially vulnerable communities",
    "primary_causes": ["Greenhouse gas emissions", "Deforestation", "Industrial processes"],
    "key_metrics": {
        "global_temp_increase": 1.1,  # degrees Celsius since 1880
        "co2_levels": 421,  # parts per million
        "sea_level_rise": 21.6  # cm since 1880
    },
    "data_sources": [
        "NASA Climate Data",
        "IPCC Reports",
        "NOAA Temperature Records",
        "World Bank Climate Database"
    ]
}

# Display information
print(f"Issue: {climate_change_info['issue']}")
print(f"Affected: {climate_change_info['affected_population']}")

print("\nKey Metrics:")
for metric, value in climate_change_info['key_metrics'].items():
    print(f"  {metric}: {value}")

print("\nData Sources:")
for source in climate_change_info['data_sources']:
    print(f"  - {source}")
# Out:
# Issue: Climate Change
# Affected: All humans, especially vulnerable communities
#
# Key Metrics:
#   global_temp_increase: 1.1
#   co2_levels: 421
#   sea_level_rise: 21.6
#
# Data Sources:
#   - NASA Climate Data
#   - IPCC Reports
#   - NOAA Temperature Records
#   - World Bank Climate Database

# %% [markdown]
# ## Part 5: Your Turn - Create Your Own Social Issue Profile
#
# Now it's your turn! Create a dictionary for a social issue you care about.

# %%
# TODO: Create your own social issue dictionary
# Replace the example below with information about an issue you care about

my_social_issue = {
    "issue": "Systemic inefficiencies in the clothing reuse market (Spain)",
    "affected_population": "Urban consumers and local reuse ecosystems in high-income cities",
    "primary_causes": ["Fragmentation and lack of coordination within the clothing reuse market",
                       "Insufficient producer responsibility and weak institutional incentives for reuse",
                       "Behavioral and cultural barriers driven by poor market design and low convenience"],
    "key_metrics": {
        "Share of post-consumer textiles captured by formal collection systems_%": 12,  # Add real numbers if you know them
        "Reuse rate within collected textiles after sorting_ %": 63,
        "Textile waste generated per capita per year": 25,
        "Share of population with regular proximity to a textile collection point": "-"
    },
    "data_sources": [
        "Open data initiative of the Government of Spain https://datos.gob.es/en/",
        "Ministerio para la Transición Ecológica (MITECO) https://www.miteco.gob.es/es.html",
        "Instituto Nacional de Estadística (INE) https://www.ine.es/",
        "Eurostat https://ec.europa.eu/eurostat",
        "EU Science Hub (JRC) https://joint-research-centre.ec.europa.eu/index_en",
        "https://psdata.un.org/",
        "https://www.humana-spain.org/"
    ]
}

# Display your issue information
print("MY SOCIAL ISSUE PROFILE")
print("=" * 25)
print(f"Issue: {my_social_issue['issue']}")
print(f"Affected Population: {my_social_issue['affected_population']}")

print("\nPrimary Causes:")
for cause in my_social_issue['primary_causes']:
    print(f"  • {cause}")

print("\nPotential Data Sources:")
for source in my_social_issue['data_sources']:
    print(f"  • {source}")
# Out:
# MY SOCIAL ISSUE PROFILE
# =========================
# Issue: Systemic inefficiencies in the clothing reuse market (Spain)
# Affected Population: Urban consumers and local reuse ecosystems in high-income cities
#
# Primary Causes:
#   • Fragmentation and lack of coordination within the clothing reuse market
#   • Insufficient producer responsibility and weak institutional incentives for reuse
#   • Behavioral and cultural barriers driven by poor market design and low convenience
#
# Potential Data Sources:
#   • https://datos.gob.es/en/
#   • Ministerio para la Transición Ecológica (MITECO) https://www.miteco.gob.es/es.html
#   • Instituto Nacional de Estadística (INE) https://www.ine.es/
#   • Academic research?

# %% [markdown]
# ## Part 6: Simple Functions - Making Code Reusable
#
# Functions let us create reusable pieces of code. This is helpful when working with data!

# %%
def calculate_percentage(part, total):
    """Calculate what percentage 'part' is of 'total'."""
    percentage = (part / total) * 100
    return round(percentage, 1)

def format_large_number(number):
    """Format large numbers with commas for readability."""
    return f"{number:,}"

# Test our functions with education statistics
global_children = 2_200_000_000  # approximate number of children worldwide
out_of_school = 244_000_000  # children out of school

out_of_school_percentage = calculate_percentage(out_of_school, global_children)

print("GLOBAL EDUCATION STATISTICS")
print("=" * 30)
print(f"Total children worldwide: {format_large_number(global_children)}")
print(f"Children out of school: {format_large_number(out_of_school)}")
print(f"Percentage out of school: {out_of_school_percentage}%")

# Calculate children IN school
in_school = global_children - out_of_school
in_school_percentage = calculate_percentage(in_school, global_children)
print(f"Children in school: {format_large_number(in_school)} ({in_school_percentage}%)")
# Out:
# GLOBAL EDUCATION STATISTICS
# ==============================
# Total children worldwide: 2,200,000,000
# Children out of school: 244,000,000
# Percentage out of school: 11.1%
# Children in school: 1,956,000,000 (88.9%)

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've completed your first Python tutorial for social impact! You've learned:
#
# ✅ **Variables and data types** - storing information
# ✅ **Numbers and calculations** - working with statistics
# ✅ **Lists** - organizing multiple items
# ✅ **Dictionaries** - structuring related data
# ✅ **Functions** - creating reusable code
#
# ## 📝 Assignment Preparation
#
# For your Week 1 assignment, you'll create a "hello world" notebook that:
# 1. Introduces yourself
# 2. Describes a social issue you care about
# 3. Lists potential data sources
# 4. Includes some basic calculations
# 5. Gets uploaded to your GitHub repository
#
# Use the code patterns you learned here as a starting point!
#
# ## Next Steps
# - Complete the Week 1 assignment
# - Set up your GitHub repository
# - Get ready for Week 2: Working with real datasets using Pandas!
